# %%
import pandas as pd 
import numpy as np

# %%
#!pip install pandas numpy openpyxl

# %%
# !pwd
# Out:
# /Users/awf/Projects/python/streamlit/traitement_sae

# %%
#filename = 'C:/Users/albert-marc.talla/Desktop/test/Taux de régularité DSP - 18092024131617.xlsx'

# %%
#!pip install openpyxl
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
filename = "./mobirecord_declarations_export.xlsx"
df = pd.read_excel(filename)

# %%
df.head(50)
# Out:
#     Numéro                Statut    Création Heure création Date évènement  \
# 0    31097              En cours  21/08/2024          09:18     21/08/2024
# 1    31096              En cours  21/08/2024          09:00     21/08/2024
# 2    31095              En cours  21/08/2024          07:13     21/08/2024
# 3    31094              En cours  21/08/2024          07:11     21/08/2024
# 4    31093              En cours  21/08/2024          07:08     21/08/2024
# 5    31092              En cours  21/08/2024          06:59     21/08/2024
# 6    31091              En cours  21/08/2024          06:56     21/08/2024
# 7    31090              En cours  21/08/2024          06:44     21/08/2024
# 8    31089              En cours  20/08/2024          23:40     20/08/2024
# 9    31088              En cours  20/08/2024          23:37     20/08/2024
# 10   31087              En cours  20/08/2024          18:03     20/08/2024
# 11   31086              En cours  20/08/2024          17:53     20/08/2024
# 12   31085              En cours  20/08/2024          17:04     20/08/2024
# 13   31084              En cours  20/08/2024          16:05     20/08/2024
# 14   31083              En cours  20/08/2024          15:08     20/08/2024
# 15   31081              En cours  20/08/2024          14:01     20/08/2024
# 16   31080              En cours  20/08/2024          13:29     20/08/2024
# 17   31082              En cours  20/08/2024          14:45     20/08/2024
# 18   31079              En cours  20/08/2024          12:40     20/08/2024
# 19   31078              En cours  20/08/2024          11:54     20/08/2024
# 20   31077              En cours  20/08/2024          09:22     20/08/2024
# 21   31076              En cours  20/08/2024          08:25     20/08/2024
# 22   31075              En cours  19/08/2024          19:20     19/08/2024
# 23   31074              En cours  19/08/2024          18:00     19/08/2024
# 24   31072              En cours  19/08/2024          17:34     19/08/2024
# 25   31070              En cours  19/08/2024          17:01     19/08/2024
# 26   31069              En cours  19/08/2024          16:57     19/08/2024
# 27   31071              En cours  19/08/2024          17:05     19/08/2024
# 28   31073              En cours  19/08/2024          17:38     19/08/2024
# 29   31068              En cours  19/08/2024          16:54     19/08/2024
# 30   31067              En cours  19/08/2024          14:20     19/08/2024
# 31   31066              En cours  19/08/2024          14:15     19/08/2024
# 32   31065              En cours  19/08/2024          11:40     19/08/2024
# 33   31064              En cours  19/08/2024          11:26     19/08/2024
# 34   31063              En cours  19/08/2024          06:50     19/08/2024
# 35   31062              En cours  19/08/2024          06:30     19/08/2024
# 36   31061  Traité par l'atelier  18/08/2024          19:34     18/08/2024
# 37   31060              En cours  17/08/2024          17:40     17/08/2024
# 38   31059              En cours  17/08/2024          15:15     17/08/2024
# 39   31058              En cours  17/08/2024          13:51     17/08/2024
# 40   31057              En cours  17/08/2024          13:50     17/08/2024
# 41   31056              En cours  17/08/2024          13:49     17/08/2024
# 42   31055              En cours  17/08/2024          13:47     17/08/2024
# 43   31054              En cours  17/08/2024          11:01     17/08/2024
# 44   31053              En cours  17/08/2024          09:42     17/08/2024
# 45   31051              En cours  17/08/2024          08:33     17/08/2024
# 46   31052              En cours  17/08/2024          08:43     17/08/2024
# 47   31050              En cours  17/08/2024          06:32     17/08/2024
# 48   31049              En cours  17/08/2024          06:06     17/08/2024
# 49   31048              En cours  17/08/2024          06:04     17/08/2024
#
#    Heure début Heure fin                   Déclarant  \
# 0        09:03     09:17       MALKI MOURAD (606363)
# 1        07:13       NaN       MALKI MOURAD (606363)
# 2        07:11       NaN       MALKI MOURAD (606363)
# 3        07:08       NaN       MALKI MOURAD (606363)
# 4        07:06       NaN       MALKI MOURAD (606363)
# 5        06:56       NaN       MALKI MOURAD (606363)
# 6        06:44       NaN       MALKI MOURAD (606363)
# 7        06:24       NaN       MALKI MOURAD (606363)
# 8        23:38       NaN       BENABBAS ALI (606236)
# 9        23:36       NaN       BENABBAS ALI (606236)
# 10       17:48     18:40        AROUI FARID (606578)
# 11       17:38       NaN        AROUI FARID (606578)
# 12       16:10     16:24        AROUI FARID (606578)
# 13       15:40       NaN   SLIMANE SULLEIMAN (12090)
# 14       14:01       NaN   SLIMANE SULLEIMAN (12090)
# 15       13:29       NaN   SLIMANE SULLEIMAN (12090)
# 16       13:10     13:25   SLIMANE SULLEIMAN (12090)
# 17       13:06       NaN        AROUI FARID (606578)
# 18       12:38       NaN        AROUI FARID (606578)
# 19       12:24     13:30   SLIMANE SULLEIMAN (12090)
# 20       08:25       NaN  ZEGHOUDI MOHAMMED (605835)
# 21       08:18       NaN  ZEGHOUDI MOHAMMED (605835)
# 22       17:45       NaN        AROUI FARID (606578)
# 23       17:38       NaN        AROUI FARID (606578)
# 24       17:33       NaN        AROUI FARID (606578)
# 25       16:58       NaN        AROUI FARID (606578)
# 26       16:55       NaN        AROUI FARID (606578)
# 27       16:05     17:04        AROUI FARID (606578)
# 28       15:25       NaN        AROUI FARID (606578)
# 29       14:20       NaN        AROUI FARID (606578)
# 30       14:16       NaN        AROUI FARID (606578)
# 31       12:56       NaN        AROUI FARID (606578)
# 32       11:26       NaN  ZEGHOUDI MOHAMMED (605835)
# 33       06:50       NaN  ZEGHOUDI MOHAMMED (605835)
# 34       06:44       NaN  ZEGHOUDI MOHAMMED (605835)
# 35       06:19       NaN       MALKI MOURAD (606363)
# 36       19:15     19:40        AROUI FARID (606578)
# 37       15:16       NaN   N DIAYE ALASSANE (606358)
# 38       13:51       NaN   N DIAYE ALASSANE (606358)
# 39       13:50       NaN   N DIAYE ALASSANE (606358)
# 40       13:49       NaN   N DIAYE ALASSANE (606358)
# 41       13:48       NaN   N DIAYE ALASSANE (606358)
# 42       11:45       NaN   N DIAYE ALASSANE (606358)
# 43       09:42       NaN        AROUI FARID (606578)
# 44       08:43       NaN        AROUI FARID (606578)
# 45       08:24       NaN        AROUI FARID (606578)
# 46       06:58     11:24        AROUI FARID (606578)
# 47       05:15       NaN        AROUI FARID (606578)
# 48       05:00       NaN        AROUI FARID (606578)
# 49       04:45       NaN        AROUI FARID (606578)
#
#                                 Agent Catégorie personnel  Matériel  \
# 0                                 NaN                 NaN       NaN
# 1            JALLOUL MOHAMED (606783)                COND  207023.0
# 2           JOLY CHRISTOPHER (606743)                COND  207024.0
# 3            KHARROUBI WALID (606705)                COND       NaN
# 4            BERANGER JEREMY (606560)                COND       NaN
# 5              AGNUS LAURENT (605597)                COND  201366.0
# 6              AVRIL GEORGES (606543)                COND  203029.0
# 7             GUIYOULE BRUCE (606774)                COND  203029.0
# 8           RAJASINGAM KEVIN (606727)                COND  201064.0
# 9     RAHERINIAINA JEAN ERIC (606474)                COND  201049.0
# 10               DICKO SEYDOU (12122)                COND       NaN
# 11        KHENNOUCI BELKACEM (606233)                COND  201046.0
# 12           MARIR ABDESSLAM (606572)                COND  202030.0
# 13             AGHROU YASSIN (606446)                COND  201384.0
# 14           DEROCHE JACQUES (606308)                COND  207025.0
# 15           MARIR ABDESSLAM (606572)                COND  201378.0
# 16           DELGADO OLIVIER (606268)                COND  201067.0
# 17           DEROCHE JACQUES (606308)                COND  207025.0
# 18           MATILI MOHAMMED (606157)                COND       NaN
# 19             BAWALA PRINCE (606781)                COND  201047.0
# 20              KHATIB MAJED (606874)                COND       NaN
# 21                BLAIN ERIC (606315)                COND       NaN
# 22              CHADET ANAÏS (606583)                COND  231005.0
# 23          ZAMI JEAN-DANIEL (606777)                COND       NaN
# 24                                NaN                 NaN  201406.0
# 25              GULSEN KEREM (606805)                COND  201070.0
# 26            MAGHRI MIMOUNE (606622)                COND  201398.0
# 27      ATIGUI MOHAMED YCHEM (606430)                COND       NaN
# 28            BALTYDE LEONCE (606706)                COND       NaN
# 29           PALMOT ROHWANNE (606902)                COND       NaN
# 30            ATIGUI MOHAMED (606286)                COND       NaN
# 31          FOUDRIN BRIGITTE (606802)                COND       NaN
# 32          DALODIERE YOUNES (606764)                COND       NaN
# 33             CAMARA MALAHA (606094)                COND       NaN
# 34        ROUAIGHIA ABDALLAH (606708)                COND       NaN
# 35            BALTYDE LEONCE (606706)                COND  201387.0
# 36   BORREGO DOMINGUES CLINT (606553)                COND  201398.0
# 37             ROBERT DAMIEN (605964)               SEDEN       NaN
# 38             CAUSIN GIANNI (606840)                COND  202030.0
# 39             KANTE CHECKNA (606780)                COND       NaN
# 40              GULSEN KEREM (606805)                COND       NaN
# 41      ATIGUI MOHAMED YCHEM (606430)                COND       NaN
# 42             BIQUE MELISSA (606376)                COND       NaN
# 43          SEYDI ABOUBAKARY (606894)                COND       NaN
# 44             CAMARA MALAHA (606094)                COND       NaN
# 45  ARAUJO DA SILVA DANIELLE (606886)                COND       NaN
# 46        ZEMMOURI ABDELKRIM (606230)                COND       NaN
# 47             TOUTOU DJAMEL (606734)                COND       NaN
# 48             TOUTOU DJAMEL (606734)                COND       NaN
# 49           KHARROUBI WALID (606705)                COND  201065.0
#
#                  Ligne                                     Direction  \
# 0                  NaN                                           NaN
# 1                  NaN                                           NaN
# 2                  NaN                                           NaN
# 3                  NaN                                           NaN
# 4                  NaN                                           NaN
# 5    519-519-034 || 34     Gare de Savigny Nandy via Pavillon Bouret
# 6    519-519-034 || 34     Gare de Savigny Nandy via Pavillon Bouret
# 7    519-519-131 || 32  Gare de Savigny-le-Temple Nandy via Aubépine
# 8    519-519-051 || 51                                           NaN
# 9                  NaN                                           NaN
# 10   519-519-110 || 53                                           NaN
# 11                 NaN                                           NaN
# 12  519-519-100 || 100                      Gare de Lieusaint Moissy
# 13  519-519-100 || 100                         Toutes les directions
# 14   519-519-050 || 50                                           NaN
# 15  519-519-100 || 100                         Toutes les directions
# 16   519-519-122 || 21                     LIEUSAINT MOISSY GARE RER
# 17   519-519-050 || 50                                           NaN
# 18   519-519-002 || 02                                           NaN
# 19   519-519-051 || 51                                           NaN
# 20                 NaN                                           NaN
# 21                 NaN                                           NaN
# 22   519-519-129 || 23           Gare de Lieusaint Moissy via Mairie
# 23   519-519-050 || 50                                           NaN
# 24                 NaN                                           NaN
# 25                 NaN                                           NaN
# 26   519-519-132 || 31                                Gare de Cesson
# 27  519-519-100 || 100                                           NaN
# 28  519-519-100 || 100                                           NaN
# 29  519-519-100 || 100                                           NaN
# 30                 NaN                                           NaN
# 31                 NaN                                           NaN
# 32                 NaN                                           NaN
# 33                 NaN                                           NaN
# 34                 NaN                                           NaN
# 35  519-519-100 || 100                                           NaN
# 36   519-519-139 || 33  Gare de Savigny-le-Temple Nandy via Aubépine
# 37                 NaN                                           NaN
# 38                 NaN                                           NaN
# 39                 NaN                                           NaN
# 40                 NaN                                           NaN
# 41                 NaN                                           NaN
# 42                 NaN                                           NaN
# 43                 NaN                                           NaN
# 44                 NaN                                           NaN
# 45                 NaN                                           NaN
# 46                 NaN                                           NaN
# 47                 NaN                                           NaN
# 48   519-519-122 || 21                                           NaN
# 49   519-519-122 || 21                                           NaN
#
#                         Type                    Catégorie  \
# 0   CIRCULATION - REGULATION                   Régulation
# 1                  VEHICULES         Signalement en ligne
# 2                  VEHICULES         Signalement au dépôt
# 3   CIRCULATION - REGULATION                  Circulation
# 4                  PERSONNEL                 Comportement
# 5                  PERSONNEL                 Comportement
# 6                  PERSONNEL                 Comportement
# 7                  PERSONNEL                      Absence
# 8                  PERSONNEL  Incident pendant le service
# 9                  VEHICULES         Signalement en ligne
# 10                 PERSONNEL                 Comportement
# 11                 VEHICULES         Signalement en ligne
# 12                 PERSONNEL  Incident pendant le service
# 13                 VEHICULES         Signalement en ligne
# 14                 VEHICULES         Signalement en ligne
# 15                 VEHICULES         Signalement au dépôt
# 16  CIRCULATION - REGULATION                   Régulation
# 17                 VEHICULES         Signalement en ligne
# 18                 PERSONNEL                 Comportement
# 19                 PERSONNEL                 Comportement
# 20                 PERSONNEL                 Comportement
# 21                 PERSONNEL                 Comportement
# 22                  ACCIDENT                     Matériel
# 23                 PERSONNEL                 Comportement
# 24                 VEHICULES         Signalement en ligne
# 25                 VEHICULES         Signalement en ligne
# 26                 VEHICULES         Signalement en ligne
# 27                 PERSONNEL                 Comportement
# 28  CIRCULATION - REGULATION                  Circulation
# 29                 PERSONNEL      Retard prise de service
# 30                 PERSONNEL                 Comportement
# 31                 PERSONNEL                      Absence
# 32                 PERSONNEL                      Absence
# 33                 PERSONNEL                 Comportement
# 34                 PERSONNEL  Incident pendant le service
# 35                 PERSONNEL      Retard prise de service
# 36                 VEHICULES         Signalement en ligne
# 37                 PERSONNEL                 Comportement
# 38                  ACCIDENT                     Matériel
# 39                 PERSONNEL                 Comportement
# 40                 PERSONNEL                 Comportement
# 41                 PERSONNEL                 Comportement
# 42                 PERSONNEL                      Absence
# 43                 PERSONNEL                      Absence
# 44                 PERSONNEL                 Comportement
# 45                 PERSONNEL                      Absence
# 46                 PERSONNEL                 Comportement
# 47                 PERSONNEL                 Comportement
# 48                 PERSONNEL                 Comportement
# 49                 VEHICULES         Signalement en ligne
#
#                    Sous-catégorie                       Consequences  \
# 0                          Retard        Réseau interrompu / retardé
# 1                        Bloquant                                NaN
# 2                    Non Bloquant                                NaN
# 3          Présence sur les voies                     Ligne retardée
# 4                         Positif                                NaN
# 5                         Positif                                NaN
# 6                         Positif                                NaN
# 7       Absence - N'a pas prévenu                                NaN
# 8              Problème personnel                                NaN
# 9                    Non Bloquant                                NaN
# 10                        Positif                                NaN
# 11                   Non Bloquant                                NaN
# 12                         Erreur                   Course partielle
# 13                       Bloquant                                NaN
# 14                       Bloquant                                NaN
# 15                       Bloquant                                NaN
# 16  Interventions service interne                                NaN
# 17                       Bloquant  Ligne partielle, Course partielle
# 18                        Positif                     Sans incidence
# 19                        Positif                                NaN
# 20                        Positif                     Ligne retardée
# 21                        Positif                                NaN
# 22   Collision avec obstacle fixe                                NaN
# 23                    Inapproprié                     Ligne retardée
# 24                   Non Bloquant                                NaN
# 25                       Bloquant                     Sans incidence
# 26                       Bloquant                Course non-réalisée
# 27                        Positif                     Sans incidence
# 28                 Embouteillages                                NaN
# 29                N'a pas prévenu                     Sans incidence
# 30                        Positif                     Sans incidence
# 31            Absence - A prévenu                                NaN
# 32            Absence - A prévenu                                NaN
# 33                        Positif                                NaN
# 34                         Erreur                    Ligne partielle
# 35                N'a pas prévenu                                NaN
# 36                       Bloquant                Course non-réalisée
# 37                        Positif                                NaN
# 38   Collision avec obstacle fixe                                NaN
# 39                        Positif                                NaN
# 40                        Positif                                NaN
# 41                        Positif                                NaN
# 42      Absence - N'a pas prévenu                                NaN
# 43            Absence - A prévenu                     Sans incidence
# 44                        Positif                                NaN
# 45      Absence - N'a pas prévenu                     Sans incidence
# 46                        Positif                     Sans incidence
# 47                        Positif                                NaN
# 48                        Positif                                NaN
# 49                       Bloquant                Course non-réalisée
#
#                                           Précisions
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                          Véhicules
# 4                                      disponibilité
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                          formation, disponibilité
# 11                           Billetique, Pupitre SAE
# 12                                        Conducteur
# 13                                               NaN
# 14                                               PMR
# 15                                               NaN
# 16                                       Contrôleurs
# 17                                               PMR
# 18                          disponibilité, formation
# 19                                     disponibilité
# 20                                         formation
# 21                                     disponibilité
# 22                                   Dégâts véhicule
# 23                                        Discipline
# 24                                         Girouette
# 25                                               NaN
# 26                                               NaN
# 27                                     disponibilité
# 28                                               NaN
# 29                                               NaN
# 30                                     disponibilité
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                        Conducteur
# 35                                               NaN
# 36                                      Voyant Rouge
# 37                                     disponibilité
# 38                                   Dégâts véhicule
# 39  formation, Heures supplémentaires, disponibilité
# 40             Heures supplémentaires, disponibilité
# 41             disponibilité, Heures supplémentaires
# 42                                               NaN
# 43                                               NaN
# 44                                     disponibilité
# 45                                               NaN
# 46                                     disponibilité
# 47                                     disponibilité
# 48                                     disponibilité
# 49                                      Voyant Rouge

# %%
#filename = 'C:/Users/albert-marc.talla/Desktop/test/Taux de régularité DSP - 18092024131617.xlsx'

df1 = pd.read_excel(filename, header=11)

# %%
df1.head(55)
# Out:
#     31087              En cours  20/08/2024  18:03 20/08/2024.1  17:48  18:40  \
# 0   31086              En cours  20/08/2024  17:53   20/08/2024  17:38    NaN
# 1   31085              En cours  20/08/2024  17:04   20/08/2024  16:10  16:24
# 2   31084              En cours  20/08/2024  16:05   20/08/2024  15:40    NaN
# 3   31083              En cours  20/08/2024  15:08   20/08/2024  14:01    NaN
# 4   31081              En cours  20/08/2024  14:01   20/08/2024  13:29    NaN
# 5   31080              En cours  20/08/2024  13:29   20/08/2024  13:10  13:25
# 6   31082              En cours  20/08/2024  14:45   20/08/2024  13:06    NaN
# 7   31079              En cours  20/08/2024  12:40   20/08/2024  12:38    NaN
# 8   31078              En cours  20/08/2024  11:54   20/08/2024  12:24  13:30
# 9   31077              En cours  20/08/2024  09:22   20/08/2024  08:25    NaN
# 10  31076              En cours  20/08/2024  08:25   20/08/2024  08:18    NaN
# 11  31075              En cours  19/08/2024  19:20   19/08/2024  17:45    NaN
# 12  31074              En cours  19/08/2024  18:00   19/08/2024  17:38    NaN
# 13  31072              En cours  19/08/2024  17:34   19/08/2024  17:33    NaN
# 14  31070              En cours  19/08/2024  17:01   19/08/2024  16:58    NaN
# 15  31069              En cours  19/08/2024  16:57   19/08/2024  16:55    NaN
# 16  31071              En cours  19/08/2024  17:05   19/08/2024  16:05  17:04
# 17  31073              En cours  19/08/2024  17:38   19/08/2024  15:25    NaN
# 18  31068              En cours  19/08/2024  16:54   19/08/2024  14:20    NaN
# 19  31067              En cours  19/08/2024  14:20   19/08/2024  14:16    NaN
# 20  31066              En cours  19/08/2024  14:15   19/08/2024  12:56    NaN
# 21  31065              En cours  19/08/2024  11:40   19/08/2024  11:26    NaN
# 22  31064              En cours  19/08/2024  11:26   19/08/2024  06:50    NaN
# 23  31063              En cours  19/08/2024  06:50   19/08/2024  06:44    NaN
# 24  31062              En cours  19/08/2024  06:30   19/08/2024  06:19    NaN
# 25  31061  Traité par l'atelier  18/08/2024  19:34   18/08/2024  19:15  19:40
# 26  31060              En cours  17/08/2024  17:40   17/08/2024  15:16    NaN
# 27  31059              En cours  17/08/2024  15:15   17/08/2024  13:51    NaN
# 28  31058              En cours  17/08/2024  13:51   17/08/2024  13:50    NaN
# 29  31057              En cours  17/08/2024  13:50   17/08/2024  13:49    NaN
# 30  31056              En cours  17/08/2024  13:49   17/08/2024  13:48    NaN
# 31  31055              En cours  17/08/2024  13:47   17/08/2024  11:45    NaN
# 32  31054              En cours  17/08/2024  11:01   17/08/2024  09:42    NaN
# 33  31053              En cours  17/08/2024  09:42   17/08/2024  08:43    NaN
# 34  31051              En cours  17/08/2024  08:33   17/08/2024  08:24    NaN
# 35  31052              En cours  17/08/2024  08:43   17/08/2024  06:58  11:24
# 36  31050              En cours  17/08/2024  06:32   17/08/2024  05:15    NaN
# 37  31049              En cours  17/08/2024  06:06   17/08/2024  05:00    NaN
# 38  31048              En cours  17/08/2024  06:04   17/08/2024  04:45    NaN
# 39  31047              En cours  16/08/2024  22:18   16/08/2024  22:12    NaN
# 40  31046              En cours  16/08/2024  17:35   16/08/2024  15:40    NaN
# 41  31045              En cours  16/08/2024  15:39   16/08/2024  15:38    NaN
# 42  31044  Refusé par l'atelier  16/08/2024  14:43   16/08/2024  14:22    NaN
# 43  31043              En cours  16/08/2024  14:21   16/08/2024  14:20    NaN
# 44  31042              En cours  16/08/2024  14:20   16/08/2024  14:12    NaN
# 45  31041  Refusé par l'atelier  16/08/2024  14:12   16/08/2024  14:09    NaN
# 46  31040              En cours  16/08/2024  14:09   16/08/2024  12:17    NaN
# 47  31038              En cours  16/08/2024  11:21   16/08/2024  11:08  11:28
# 48  31039              En cours  16/08/2024  11:24   16/08/2024  09:34  13:04
# 49  31033              En cours  15/08/2024  16:43   16/08/2024  09:30  13:03
# 50  31032              En cours  15/08/2024  16:38   16/08/2024  09:24  13:03
# 51  31036  Refusé par l'atelier  16/08/2024  06:45   16/08/2024  06:39    NaN
# 52  31035              En cours  16/08/2024  05:59   16/08/2024  05:55    NaN
# 53  31037              En cours  16/08/2024  10:41   16/08/2024  05:00    NaN
# 54  31034  Refusé par l'atelier  15/08/2024  17:17   15/08/2024  17:15  17:43
#
#           AROUI FARID (606578)               DICKO SEYDOU (12122)   COND  \
# 0         AROUI FARID (606578)        KHENNOUCI BELKACEM (606233)   COND
# 1         AROUI FARID (606578)           MARIR ABDESSLAM (606572)   COND
# 2    SLIMANE SULLEIMAN (12090)             AGHROU YASSIN (606446)   COND
# 3    SLIMANE SULLEIMAN (12090)           DEROCHE JACQUES (606308)   COND
# 4    SLIMANE SULLEIMAN (12090)           MARIR ABDESSLAM (606572)   COND
# 5    SLIMANE SULLEIMAN (12090)           DELGADO OLIVIER (606268)   COND
# 6         AROUI FARID (606578)           DEROCHE JACQUES (606308)   COND
# 7         AROUI FARID (606578)           MATILI MOHAMMED (606157)   COND
# 8    SLIMANE SULLEIMAN (12090)             BAWALA PRINCE (606781)   COND
# 9   ZEGHOUDI MOHAMMED (605835)              KHATIB MAJED (606874)   COND
# 10  ZEGHOUDI MOHAMMED (605835)                BLAIN ERIC (606315)   COND
# 11        AROUI FARID (606578)              CHADET ANAÏS (606583)   COND
# 12        AROUI FARID (606578)          ZAMI JEAN-DANIEL (606777)   COND
# 13        AROUI FARID (606578)                                NaN    NaN
# 14        AROUI FARID (606578)              GULSEN KEREM (606805)   COND
# 15        AROUI FARID (606578)            MAGHRI MIMOUNE (606622)   COND
# 16        AROUI FARID (606578)      ATIGUI MOHAMED YCHEM (606430)   COND
# 17        AROUI FARID (606578)            BALTYDE LEONCE (606706)   COND
# 18        AROUI FARID (606578)           PALMOT ROHWANNE (606902)   COND
# 19        AROUI FARID (606578)            ATIGUI MOHAMED (606286)   COND
# 20        AROUI FARID (606578)          FOUDRIN BRIGITTE (606802)   COND
# 21  ZEGHOUDI MOHAMMED (605835)          DALODIERE YOUNES (606764)   COND
# 22  ZEGHOUDI MOHAMMED (605835)             CAMARA MALAHA (606094)   COND
# 23  ZEGHOUDI MOHAMMED (605835)        ROUAIGHIA ABDALLAH (606708)   COND
# 24       MALKI MOURAD (606363)            BALTYDE LEONCE (606706)   COND
# 25        AROUI FARID (606578)   BORREGO DOMINGUES CLINT (606553)   COND
# 26   N DIAYE ALASSANE (606358)             ROBERT DAMIEN (605964)  SEDEN
# 27   N DIAYE ALASSANE (606358)             CAUSIN GIANNI (606840)   COND
# 28   N DIAYE ALASSANE (606358)             KANTE CHECKNA (606780)   COND
# 29   N DIAYE ALASSANE (606358)              GULSEN KEREM (606805)   COND
# 30   N DIAYE ALASSANE (606358)      ATIGUI MOHAMED YCHEM (606430)   COND
# 31   N DIAYE ALASSANE (606358)             BIQUE MELISSA (606376)   COND
# 32        AROUI FARID (606578)          SEYDI ABOUBAKARY (606894)   COND
# 33        AROUI FARID (606578)             CAMARA MALAHA (606094)   COND
# 34        AROUI FARID (606578)  ARAUJO DA SILVA DANIELLE (606886)   COND
# 35        AROUI FARID (606578)        ZEMMOURI ABDELKRIM (606230)   COND
# 36        AROUI FARID (606578)             TOUTOU DJAMEL (606734)   COND
# 37        AROUI FARID (606578)             TOUTOU DJAMEL (606734)   COND
# 38        AROUI FARID (606578)           KHARROUBI WALID (606705)   COND
# 39       BENABBAS ALI (606236)              ASSOU MOHAMED (12036)   COND
# 40   SLIMANE SULLEIMAN (12090)          SLIMANE SULLEIMAN (12090)   COND
# 41   SLIMANE SULLEIMAN (12090)          BENSADOK SOFIANE (606761)   COND
# 42        AROUI FARID (606578)       AKNOUCHE A ABDENOUR (606856)   COND
# 43        AROUI FARID (606578)            ATIGUI MOHAMED (606286)   COND
# 44        AROUI FARID (606578)      ATIGUI MOHAMED YCHEM (606430)   COND
# 45        AROUI FARID (606578)       AKNOUCHE A ABDENOUR (606856)   COND
# 46        AROUI FARID (606578)          SEYDI ABOUBAKARY (606894)   COND
# 47        AROUI FARID (606578)           DE SOUSA ESTEVE (607993)    NaN
# 48        AROUI FARID (606578)             CAMARA MALAHA (606094)   COND
# 49   SLIMANE SULLEIMAN (12090)             CAMARA MALAHA (606094)   COND
# 50   SLIMANE SULLEIMAN (12090)         DOUCOURE SOUAIBOU (606904)   COND
# 51    ALDONER JOACHIM (606503)              CORNU JEROME (605653)   COND
# 52       MALKI MOURAD (606363)             FOURTI SOFYAN (606866)   COND
# 53        AROUI FARID (606578)             KANTE CHECKNA (606780)   COND
# 54   SLIMANE SULLEIMAN (12090)             MAHMOUD MEHDI (606742)   COND
#
#     Unnamed: 10    519-519-110 || 53  \
# 0      201046.0                  NaN
# 1      202030.0   519-519-100 || 100
# 2      201384.0   519-519-100 || 100
# 3      207025.0    519-519-050 || 50
# 4      201378.0   519-519-100 || 100
# 5      201067.0    519-519-122 || 21
# 6      207025.0    519-519-050 || 50
# 7           NaN    519-519-002 || 02
# 8      201047.0    519-519-051 || 51
# 9           NaN                  NaN
# 10          NaN                  NaN
# 11     231005.0    519-519-129 || 23
# 12          NaN    519-519-050 || 50
# 13     201406.0                  NaN
# 14     201070.0                  NaN
# 15     201398.0    519-519-132 || 31
# 16          NaN   519-519-100 || 100
# 17          NaN   519-519-100 || 100
# 18          NaN   519-519-100 || 100
# 19          NaN                  NaN
# 20          NaN                  NaN
# 21          NaN                  NaN
# 22          NaN                  NaN
# 23          NaN                  NaN
# 24     201387.0   519-519-100 || 100
# 25     201398.0    519-519-139 || 33
# 26          NaN                  NaN
# 27     202030.0                  NaN
# 28          NaN                  NaN
# 29          NaN                  NaN
# 30          NaN                  NaN
# 31          NaN                  NaN
# 32          NaN                  NaN
# 33          NaN                  NaN
# 34          NaN                  NaN
# 35          NaN                  NaN
# 36          NaN                  NaN
# 37          NaN    519-519-122 || 21
# 38     201065.0    519-519-122 || 21
# 39       2405.0    519-519-127 || 24
# 40     231011.0                  NaN
# 41     203030.0                  NaN
# 42     201368.0    519-519-132 || 31
# 43          NaN                  NaN
# 44          NaN                  NaN
# 45     201408.0                  NaN
# 46          NaN                  NaN
# 47          NaN    519-519-122 || 21
# 48          NaN  519-519-077 || CITA
# 49     201050.0  519-519-077 || CITA
# 50     201050.0  519-519-077 || CITA
# 51     201411.0    519-519-034 || 34
# 52     207011.0    519-519-050 || 50
# 53     207011.0    519-519-050 || 50
# 54     201412.0    519-519-139 || 33
#
#                                      Unnamed: 12                 PERSONNEL  \
# 0                                            NaN                 VEHICULES
# 1                       Gare de Lieusaint Moissy                 PERSONNEL
# 2                          Toutes les directions                 VEHICULES
# 3                                            NaN                 VEHICULES
# 4                          Toutes les directions                 VEHICULES
# 5                      LIEUSAINT MOISSY GARE RER  CIRCULATION - REGULATION
# 6                                            NaN                 VEHICULES
# 7                                            NaN                 PERSONNEL
# 8                                            NaN                 PERSONNEL
# 9                                            NaN                 PERSONNEL
# 10                                           NaN                 PERSONNEL
# 11           Gare de Lieusaint Moissy via Mairie                  ACCIDENT
# 12                                           NaN                 PERSONNEL
# 13                                           NaN                 VEHICULES
# 14                                           NaN                 VEHICULES
# 15                                Gare de Cesson                 VEHICULES
# 16                                           NaN                 PERSONNEL
# 17                                           NaN  CIRCULATION - REGULATION
# 18                                           NaN                 PERSONNEL
# 19                                           NaN                 PERSONNEL
# 20                                           NaN                 PERSONNEL
# 21                                           NaN                 PERSONNEL
# 22                                           NaN                 PERSONNEL
# 23                                           NaN                 PERSONNEL
# 24                                           NaN                 PERSONNEL
# 25  Gare de Savigny-le-Temple Nandy via Aubépine                 VEHICULES
# 26                                           NaN                 PERSONNEL
# 27                                           NaN                  ACCIDENT
# 28                                           NaN                 PERSONNEL
# 29                                           NaN                 PERSONNEL
# 30                                           NaN                 PERSONNEL
# 31                                           NaN                 PERSONNEL
# 32                                           NaN                 PERSONNEL
# 33                                           NaN                 PERSONNEL
# 34                                           NaN                 PERSONNEL
# 35                                           NaN                 PERSONNEL
# 36                                           NaN                 PERSONNEL
# 37                                           NaN                 PERSONNEL
# 38                                           NaN                 VEHICULES
# 39                      Gare de Lieusaint Moissy                  ACCIDENT
# 40                                           NaN                 VEHICULES
# 41                                           NaN                 VEHICULES
# 42                                Gare de Cesson                 VEHICULES
# 43                                           NaN                 PERSONNEL
# 44                                           NaN                 PERSONNEL
# 45                                           NaN                 VEHICULES
# 46                                           NaN                 PERSONNEL
# 47                 Gare de Combs-La-Ville Quincy  CIRCULATION - REGULATION
# 48                                           NaN                 PERSONNEL
# 49                         Toutes les directions                 PERSONNEL
# 50                         Toutes les directions                 PERSONNEL
# 51     Gare de Savigny Nandy via Pavillon Bouret                 VEHICULES
# 52                     Gare d'Evry Courcouronnes                 PERSONNEL
# 53                                           NaN                 PERSONNEL
# 54  Gare de Savigny-le-Temple Nandy via Aubépine                 VEHICULES
#
#                    Comportement                        Positif  \
# 0          Signalement en ligne                   Non Bloquant
# 1   Incident pendant le service                         Erreur
# 2          Signalement en ligne                       Bloquant
# 3          Signalement en ligne                       Bloquant
# 4          Signalement au dépôt                       Bloquant
# 5                    Régulation  Interventions service interne
# 6          Signalement en ligne                       Bloquant
# 7                  Comportement                        Positif
# 8                  Comportement                        Positif
# 9                  Comportement                        Positif
# 10                 Comportement                        Positif
# 11                     Matériel   Collision avec obstacle fixe
# 12                 Comportement                    Inapproprié
# 13         Signalement en ligne                   Non Bloquant
# 14         Signalement en ligne                       Bloquant
# 15         Signalement en ligne                       Bloquant
# 16                 Comportement                        Positif
# 17                  Circulation                 Embouteillages
# 18      Retard prise de service                N'a pas prévenu
# 19                 Comportement                        Positif
# 20                      Absence            Absence - A prévenu
# 21                      Absence            Absence - A prévenu
# 22                 Comportement                        Positif
# 23  Incident pendant le service                         Erreur
# 24      Retard prise de service                N'a pas prévenu
# 25         Signalement en ligne                       Bloquant
# 26                 Comportement                        Positif
# 27                     Matériel   Collision avec obstacle fixe
# 28                 Comportement                        Positif
# 29                 Comportement                        Positif
# 30                 Comportement                        Positif
# 31                      Absence      Absence - N'a pas prévenu
# 32                      Absence            Absence - A prévenu
# 33                 Comportement                        Positif
# 34                      Absence      Absence - N'a pas prévenu
# 35                 Comportement                        Positif
# 36                 Comportement                        Positif
# 37                 Comportement                        Positif
# 38         Signalement en ligne                       Bloquant
# 39         Corporel et matériel   Collision avec obstacle fixe
# 40         Signalement en ligne                   Non Bloquant
# 41         Signalement au dépôt                       Bloquant
# 42         Signalement au dépôt                       Bloquant
# 43                 Comportement                        Positif
# 44                 Comportement                        Positif
# 45         Signalement au dépôt                   Non Bloquant
# 46                      Absence            Absence - A prévenu
# 47                   Régulation  Interventions service interne
# 48                 Comportement                        Positif
# 49                 Comportement                        Positif
# 50                      Absence            Absence - A prévenu
# 51         Signalement en ligne                       Bloquant
# 52                      Absence      Absence - N'a pas prévenu
# 53                 Comportement                        Positif
# 54         Signalement en ligne                       Bloquant
#
#                           Unnamed: 16  \
# 0                                 NaN
# 1                    Course partielle
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6   Ligne partielle, Course partielle
# 7                      Sans incidence
# 8                                 NaN
# 9                      Ligne retardée
# 10                                NaN
# 11                                NaN
# 12                     Ligne retardée
# 13                                NaN
# 14                     Sans incidence
# 15                Course non-réalisée
# 16                     Sans incidence
# 17                                NaN
# 18                     Sans incidence
# 19                     Sans incidence
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                    Ligne partielle
# 24                                NaN
# 25                Course non-réalisée
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# 30                                NaN
# 31                                NaN
# 32                     Sans incidence
# 33                                NaN
# 34                     Sans incidence
# 35                     Sans incidence
# 36                                NaN
# 37                                NaN
# 38                Course non-réalisée
# 39                                NaN
# 40                                NaN
# 41                                NaN
# 42                    Ligne partielle
# 43                                NaN
# 44                     Sans incidence
# 45                                NaN
# 46                     Sans incidence
# 47                     Ligne retardée
# 48                     Sans incidence
# 49                                NaN
# 50                                NaN
# 51                Course non-réalisée
# 52                     Sans incidence
# 53                                NaN
# 54                Course non-réalisée
#
#                             formation, disponibilité
# 0                            Billetique, Pupitre SAE
# 1                                         Conducteur
# 2                                                NaN
# 3                                                PMR
# 4                                                NaN
# 5                                        Contrôleurs
# 6                                                PMR
# 7                           disponibilité, formation
# 8                                      disponibilité
# 9                                          formation
# 10                                     disponibilité
# 11                                   Dégâts véhicule
# 12                                        Discipline
# 13                                         Girouette
# 14                                               NaN
# 15                                               NaN
# 16                                     disponibilité
# 17                                               NaN
# 18                                               NaN
# 19                                     disponibilité
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                        Conducteur
# 24                                               NaN
# 25                                      Voyant Rouge
# 26                                     disponibilité
# 27                                   Dégâts véhicule
# 28  formation, Heures supplémentaires, disponibilité
# 29             Heures supplémentaires, disponibilité
# 30             disponibilité, Heures supplémentaires
# 31                                               NaN
# 32                                               NaN
# 33                                     disponibilité
# 34                                               NaN
# 35                                     disponibilité
# 36                                     disponibilité
# 37                                     disponibilité
# 38                                      Voyant Rouge
# 39                         Voyageur, Dégâts véhicule
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43             disponibilité, Heures supplémentaires
# 44                                     disponibilité
# 45                           Pupitre SAE, Billetique
# 46                                               NaN
# 47                                       Contrôleurs
# 48             Heures supplémentaires, disponibilité
# 49             Heures supplémentaires, disponibilité
# 50                                               NaN
# 51                                      Voyant Rouge
# 52                                               NaN
# 53             disponibilité, Heures supplémentaires
# 54                                      Voyant Rouge

# %%
df1.columns
# Out:
# Index(['Transporteur', 'Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Semaine 2024 36', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Semaine 2024 37', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Semaine 2024 38', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Totaux', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
df1_S1=df1[['Transporteur', 'Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3',
       'Unnamed: 4']]

df1_S2=df1[['Semaine 2024 36','Unnamed: 6', 'Unnamed: 7',
       'Unnamed: 8']]

df1_S3 =df1[['Semaine 2024 37', 'Unnamed: 10', 'Unnamed: 11',
       'Unnamed: 12']]

# %%
df1_S1.head()
# Out:
#      Transporteur Semaine 2024 35    Unnamed: 2    Unnamed: 3 Unnamed: 4
# 0           Ligne   Tx conformite  Tx SI avance  Tx SI retard      Tx SI
# 1  DSP19 - SENART        0.931777      0.013608        0.0058   0.019408
# 2            TZN1        0.926288      0.015576      0.002528   0.018104
# 3              01             NaN           NaN           NaN        NaN
# 4              02        0.947664      0.015888             0   0.015888

# %%
date_S1=df1_S1.columns.to_list()[1]

df1_S1 = df1_S1.copy()
df1_S1['Date'] = date_S1

#df1_S1['Date']= date_S1
#type(date_S1)

# %%
df1_S1.head(2)
# Out:
#      Transporteur Semaine 2024 35    Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0           Ligne   Tx conformite  Tx SI avance  Tx SI retard      Tx SI
# 1  DSP19 - SENART        0.931777      0.013608        0.0058   0.019408
#
#               Date
# 0  Semaine 2024 35
# 1  Semaine 2024 35

# %%
df1_S1.columns=df1_S1.iloc[0]

# %%
df1_S1.head(2)
# Out:
# 0           Ligne  Tx conformite  Tx SI avance  Tx SI retard     Tx SI  \
# 0           Ligne  Tx conformite  Tx SI avance  Tx SI retard     Tx SI
# 1  DSP19 - SENART       0.931777      0.013608        0.0058  0.019408
#
# 0  Semaine 2024 35
# 0  Semaine 2024 35
# 1  Semaine 2024 35

# %%
df1_S1=df1_S1[2:]

# %%
df1_S1.head(2)
# Out:
# 0 Ligne Tx conformite Tx SI avance Tx SI retard     Tx SI  Semaine 2024 35
# 2  TZN1      0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 3    01           NaN          NaN          NaN       NaN  Semaine 2024 35

# %%
type(df1_S1)
#df1_S1=df1_S1.reset_index(drop=True)
# Out:
# pandas.core.frame.DataFrame

# %%
df1_S1=df1_S1.reset_index(drop=True)

# %%
df1_S1.head(2)
# Out:
# 0 Ligne Tx conformite Tx SI avance Tx SI retard     Tx SI  Semaine 2024 35
# 0  TZN1      0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1    01           NaN          NaN          NaN       NaN  Semaine 2024 35

# %%
df1_S1.rename(columns={'Semaine 2024 35':'Date'})
# Out:
# 0          Ligne Tx conformite Tx SI avance Tx SI retard     Tx SI  \
# 0           TZN1      0.926288     0.015576     0.002528  0.018104
# 1             01           NaN          NaN          NaN       NaN
# 2             02      0.947664     0.015888            0  0.015888
# 3             03      0.980887     0.009939     0.000765  0.010703
# 4             04      0.952328     0.008869      0.00388  0.012749
# 5             05           NaN          NaN          NaN       NaN
# 6             11      0.959989     0.008165     0.001633  0.009799
# 7             12      0.966903     0.013855     0.004002  0.017857
# 8             13      0.979186     0.008326     0.000308  0.008634
# 9             21      0.925339     0.011312     0.004309  0.015622
# 10            22      0.912613     0.009079     0.012322  0.021401
# 11            23      0.898671     0.036545     0.016196  0.052741
# 12            24        0.9416     0.007964     0.003792  0.011756
# 13            25      0.923048     0.008299     0.026405  0.034704
# 14            26      0.936541     0.026499     0.006974  0.033473
# 15            27      0.958333     0.014583     0.010417     0.025
# 16            31      0.954018     0.004537     0.001769  0.006305
# 17            32      0.965986     0.008098     0.000648  0.008746
# 18            33      0.943556     0.007526     0.002822  0.010348
# 19            34      0.977907     0.008337            0  0.008337
# 20            35      0.967647     0.017647     0.005882  0.023529
# 21            36      0.952116     0.021521     0.007174  0.028694
# 22            37      0.971079     0.014461     0.001112  0.015573
# 23            41      0.978846     0.015385     0.000962  0.016346
# 24            42      0.953435     0.022392     0.003053  0.025445
# 25            43      0.966056     0.014866     0.000496  0.015362
# 26            50      0.838578     0.031886     0.005664   0.03755
# 27            51      0.923581     0.011421     0.008062  0.019483
# 28            52           NaN          NaN          NaN       NaN
# 29            53      0.919954     0.005568     0.016241   0.02181
# 30            54      0.697183     0.274648     0.003521  0.278169
# 31            55      0.731602     0.047619     0.073593  0.121212
# 32           61B           NaN          NaN          NaN       NaN
# 33           61A           NaN          NaN          NaN       NaN
# 34           62B           NaN          NaN          NaN       NaN
# 35           62A           NaN          NaN          NaN       NaN
# 36           62C           NaN          NaN          NaN       NaN
# 37            63           NaN          NaN          NaN       NaN
# 38            64           NaN          NaN          NaN       NaN
# 39          CPSF      0.930016     0.032659     0.012442  0.045101
# 40          CITA      0.845931     0.010103     0.022451  0.032554
# 41  Somme finale      0.931777     0.013608       0.0058  0.019408
#
# 0              Date
# 0   Semaine 2024 35
# 1   Semaine 2024 35
# 2   Semaine 2024 35
# 3   Semaine 2024 35
# 4   Semaine 2024 35
# 5   Semaine 2024 35
# 6   Semaine 2024 35
# 7   Semaine 2024 35
# 8   Semaine 2024 35
# 9   Semaine 2024 35
# 10  Semaine 2024 35
# 11  Semaine 2024 35
# 12  Semaine 2024 35
# 13  Semaine 2024 35
# 14  Semaine 2024 35
# 15  Semaine 2024 35
# 16  Semaine 2024 35
# 17  Semaine 2024 35
# 18  Semaine 2024 35
# 19  Semaine 2024 35
# 20  Semaine 2024 35
# 21  Semaine 2024 35
# 22  Semaine 2024 35
# 23  Semaine 2024 35
# 24  Semaine 2024 35
# 25  Semaine 2024 35
# 26  Semaine 2024 35
# 27  Semaine 2024 35
# 28  Semaine 2024 35
# 29  Semaine 2024 35
# 30  Semaine 2024 35
# 31  Semaine 2024 35
# 32  Semaine 2024 35
# 33  Semaine 2024 35
# 34  Semaine 2024 35
# 35  Semaine 2024 35
# 36  Semaine 2024 35
# 37  Semaine 2024 35
# 38  Semaine 2024 35
# 39  Semaine 2024 35
# 40  Semaine 2024 35
# 41  Semaine 2024 35

# %%
print(df1_S1.columns)

print(df1_S1.head(2))
# Out:
# Index(['Ligne', 'Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI',
#        'Semaine 2024 35'],
#       dtype='object', name=0)
# 0 Ligne Tx conformite Tx SI avance Tx SI retard     Tx SI  Semaine 2024 35
# 0  TZN1      0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1    01           NaN          NaN          NaN       NaN  Semaine 2024 35

# %%
df = pd.read_excel(filename, header=11)
df.columns
# Out:
# Index(['Transporteur', 'Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Semaine 2024 36', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Semaine 2024 37', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Semaine 2024 38', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Totaux', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
# Extraire les colonnes qui contiennent le mot 'Semaine'
colonnes_semaines = [col for col in df.columns if 'Semaine' in col]

# Afficher les colonnes correspondantes
print(colonnes_semaines)
# Out:
# ['Semaine 2024 35', 'Semaine 2024 36', 'Semaine 2024 37', 'Semaine 2024 38']

# %%
# Fonction pour récupérer les paires start_week et end_week
def get_week_intervals(df):
    # Récupérer les colonnes contenant 'Semaine'
    week_columns = [col for col in df.columns if 'Semaine' in col]
    
    # Créer une liste pour stocker les paires (start_week, end_week)
    intervals = []

    for i in range(len(week_columns) - 1):
        start_week = week_columns[i]
        end_week = week_columns[i + 1]
        intervals.append((start_week, end_week))
    
    return intervals

# %%
# Récupérer les paires de semaines
week_intervals = get_week_intervals(df)

# Affichage des intervalles (start_week, end_week)
print(week_intervals)
# Out:
# [('Semaine 2024 35', 'Semaine 2024 36'), ('Semaine 2024 36', 'Semaine 2024 37'), ('Semaine 2024 37', 'Semaine 2024 38')]

# %%
# Fonction pour récupérer les colonnes entre deux semaines, sans inclure la colonne de fin
def get_columns_between_weeks_exclusive(df, start_week, end_week):
    # Initialisation de la liste des colonnes à inclure
    selected_columns = []
    include = False

    for col in df.columns:
        # Vérification si on doit commencer à inclure les colonnes
        if start_week in col:
            include = True
        # Ajout des colonnes tant qu'on est dans l'intervalle
        if include:
            # Arrêter d'ajouter les colonnes dès que la colonne de fin est atteinte
            if end_week in col:
                break
            selected_columns.append(col)
    
    return selected_columns

# %%
# Récupérer les paires de semaines
week_intervals
# Out:
# [('Semaine 2024 35', 'Semaine 2024 36'),
#  ('Semaine 2024 36', 'Semaine 2024 37'),
#  ('Semaine 2024 37', 'Semaine 2024 38')]

# %%
week_intervals[0]
# Out:
# ('Semaine 2024 35', 'Semaine 2024 36')

# %%
week_intervals[0][0]
# Out:
# 'Semaine 2024 35'

# %%
# Exemple d'utilisation
start_week = week_intervals[0][0]
end_week = week_intervals[0][1]

# Récupérer les colonnes entre deux semaines, sans inclure la colonne de fin
first_week_interval_columns = get_columns_between_weeks_exclusive(df, start_week, end_week)

# Affichage des colonnes sélectionnées
print(first_week_interval_columns)
# Out:
# ['Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']

# %%
# Récupérer les paires de semaines
week_intervals = get_week_intervals(df)

# Initialiser un dictionnaire pour stocker les colonnes par intervalle
columns_by_interval = {}

# Boucle sur chaque intervalle (start_week, end_week) pour récupérer les colonnes
for start_week, end_week in week_intervals:
    # Récupérer les colonnes pour cet intervalle spécifique
    interval_columns = get_columns_between_weeks_exclusive(df, start_week, end_week)
    # Stocker le résultat dans le dictionnaire avec l'intervalle comme clé
    columns_by_interval[(start_week, end_week)] = interval_columns

# Afficher les colonnes pour chaque intervalle
for interval, columns in columns_by_interval.items():
    print(f"Intervalle {interval}: {columns}")
# Out:
# Intervalle ('Semaine 2024 35', 'Semaine 2024 36'): ['Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']
# Intervalle ('Semaine 2024 36', 'Semaine 2024 37'): ['Semaine 2024 36', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']
# Intervalle ('Semaine 2024 37', 'Semaine 2024 38'): ['Semaine 2024 37', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12']

# %%
# Fonction pour récupérer les paires start_week et end_week, incluant la dernière semaine si non suivie
def get_week_intervals(df):
    week_columns = [col for col in df.columns if 'Semaine' in col]
    intervals = []
    for i in range(len(week_columns) - 1):
        start_week = week_columns[i]
        end_week = week_columns[i + 1]
        intervals.append((start_week, end_week))
    # Ajouter la dernière semaine seule si elle n'a pas d'intervalle suivant
    if len(week_columns) > 0:
        intervals.append((week_columns[-1], None))
    return intervals

# Fonction pour récupérer les colonnes entre deux semaines, incluant le cas où end_week est None
def get_columns_between_weeks_exclusive(df, start_week, end_week):
    selected_columns = []
    include = False
    for col in df.columns:
        if start_week in col:
            include = True
        if include:
            # Si end_week est None, inclure toutes les colonnes restantes
            if end_week is None:
                selected_columns.append(col)
            # Sinon, arrêter l'inclusion avant d'atteindre end_week
            elif end_week in col:
                break
            else:
                selected_columns.append(col)
    return selected_columns

# Récupérer les paires de semaines
week_intervals = get_week_intervals(df)

# Initialiser un dictionnaire pour stocker les colonnes par intervalle
columns_by_interval = {}

# Boucle sur chaque intervalle (start_week, end_week) pour récupérer les colonnes
for start_week, end_week in week_intervals:
    # Récupérer les colonnes pour cet intervalle spécifique
    interval_columns = get_columns_between_weeks_exclusive(df, start_week, end_week)
    # Stocker le résultat dans le dictionnaire avec l'intervalle comme clé
    columns_by_interval[(start_week, end_week)] = interval_columns

# Afficher les colonnes pour chaque intervalle
for interval, columns in columns_by_interval.items():
    print(f"Intervalle {interval}: {columns}")
# Out:
# Intervalle ('Semaine 2024 35', 'Semaine 2024 36'): ['Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']
# Intervalle ('Semaine 2024 36', 'Semaine 2024 37'): ['Semaine 2024 36', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']
# Intervalle ('Semaine 2024 37', 'Semaine 2024 38'): ['Semaine 2024 37', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12']
# Intervalle ('Semaine 2024 38', None): ['Semaine 2024 38', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Totaux', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']

# %%
columns_by_interval
# Out:
# {('Semaine 2024 35', 'Semaine 2024 36'): ['Semaine 2024 35',
#   'Unnamed: 2',
#   'Unnamed: 3',
#   'Unnamed: 4'],
#  ('Semaine 2024 36', 'Semaine 2024 37'): ['Semaine 2024 36',
#   'Unnamed: 6',
#   'Unnamed: 7',
#   'Unnamed: 8'],
#  ('Semaine 2024 37', 'Semaine 2024 38'): ['Semaine 2024 37',
#   'Unnamed: 10',
#   'Unnamed: 11',
#   'Unnamed: 12'],
#  ('Semaine 2024 38', None): ['Semaine 2024 38',
#   'Unnamed: 14',
#   'Unnamed: 15',
#   'Unnamed: 16',
#   'Totaux',
#   'Unnamed: 18',
#   'Unnamed: 19',
#   'Unnamed: 20']}

# %%
#columns

# %%
# Récupérer le premier intervalle
first_interval = list(columns_by_interval.keys())[0]

# Récupérer les colonnes correspondant au premier intervalle
first_interval_columns = columns_by_interval[first_interval]

# Créer le DataFrame S1 en sélectionnant les colonnes dans df1
S1 = df[first_interval_columns]

# Afficher le DataFrame S1
print("DataFrame S1 basé sur le premier intervalle :")
display(S1)
# Out:
# DataFrame S1 basé sur le premier intervalle :
#    Semaine 2024 35    Unnamed: 2    Unnamed: 3 Unnamed: 4
# 0    Tx conformite  Tx SI avance  Tx SI retard      Tx SI
# 1         0.931777      0.013608        0.0058   0.019408
# 2         0.926288      0.015576      0.002528   0.018104
# 3              NaN           NaN           NaN        NaN
# 4         0.947664      0.015888             0   0.015888
# 5         0.980887      0.009939      0.000765   0.010703
# 6         0.952328      0.008869       0.00388   0.012749
# 7              NaN           NaN           NaN        NaN
# 8         0.959989      0.008165      0.001633   0.009799
# 9         0.966903      0.013855      0.004002   0.017857
# 10        0.979186      0.008326      0.000308   0.008634
# 11        0.925339      0.011312      0.004309   0.015622
# 12        0.912613      0.009079      0.012322   0.021401
# 13        0.898671      0.036545      0.016196   0.052741
# 14          0.9416      0.007964      0.003792   0.011756
# 15        0.923048      0.008299      0.026405   0.034704
# 16        0.936541      0.026499      0.006974   0.033473
# 17        0.958333      0.014583      0.010417      0.025
# 18        0.954018      0.004537      0.001769   0.006305
# 19        0.965986      0.008098      0.000648   0.008746
# 20        0.943556      0.007526      0.002822   0.010348
# 21        0.977907      0.008337             0   0.008337
# 22        0.967647      0.017647      0.005882   0.023529
# 23        0.952116      0.021521      0.007174   0.028694
# 24        0.971079      0.014461      0.001112   0.015573
# 25        0.978846      0.015385      0.000962   0.016346
# 26        0.953435      0.022392      0.003053   0.025445
# 27        0.966056      0.014866      0.000496   0.015362
# 28        0.838578      0.031886      0.005664    0.03755
# 29        0.923581      0.011421      0.008062   0.019483
# 30             NaN           NaN           NaN        NaN
# 31        0.919954      0.005568      0.016241    0.02181
# 32        0.697183      0.274648      0.003521   0.278169
# 33        0.731602      0.047619      0.073593   0.121212
# 34             NaN           NaN           NaN        NaN
# 35             NaN           NaN           NaN        NaN
# 36             NaN           NaN           NaN        NaN
# 37             NaN           NaN           NaN        NaN
# 38             NaN           NaN           NaN        NaN
# 39             NaN           NaN           NaN        NaN
# 40             NaN           NaN           NaN        NaN
# 41        0.930016      0.032659      0.012442   0.045101
# 42        0.845931      0.010103      0.022451   0.032554
# 43        0.931777      0.013608        0.0058   0.019408

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns]
    # Nommer le DataFrame (par exemple, S1, S2, S3, etc.)
    dataframe_name = f"S{idx + 1}"
    # Stocker le DataFrame dans le dictionnaire
    dataframes_by_interval[dataframe_name] = df_interval
    # Afficher le DataFrame
    print(f"DataFrame {dataframe_name} basé sur l'intervalle {interval}:")
    display(df_interval.head(2))
    print("\n")

# Accéder aux DataFrames dans le dictionnaire
# Par exemple, accéder à S1
S1 = dataframes_by_interval['S1']
# Out:
# DataFrame S1 basé sur l'intervalle ('Semaine 2024 35', 'Semaine 2024 36'):
#   Semaine 2024 35    Unnamed: 2    Unnamed: 3 Unnamed: 4
# 0   Tx conformite  Tx SI avance  Tx SI retard      Tx SI
# 1        0.931777      0.013608        0.0058   0.019408
# DataFrame S2 basé sur l'intervalle ('Semaine 2024 36', 'Semaine 2024 37'):
#   Semaine 2024 36    Unnamed: 6    Unnamed: 7 Unnamed: 8
# 0   Tx conformite  Tx SI avance  Tx SI retard      Tx SI
# 1        0.921553      0.013807      0.008999   0.022806
# DataFrame S3 basé sur l'intervalle ('Semaine 2024 37', 'Semaine 2024 38'):
#   Semaine 2024 37   Unnamed: 10   Unnamed: 11 Unnamed: 12
# 0   Tx conformite  Tx SI avance  Tx SI retard       Tx SI
# 1        0.920352      0.017158      0.007891    0.025049
# DataFrame S4 basé sur l'intervalle ('Semaine 2024 38', None):
#   Semaine 2024 38   Unnamed: 14   Unnamed: 15 Unnamed: 16         Totaux  \
# 0   Tx conformite  Tx SI avance  Tx SI retard       Tx SI  Tx conformite
# 1        0.930056      0.016524       0.00765    0.024174       0.924892
#
#     Unnamed: 18   Unnamed: 19 Unnamed: 20
# 0  Tx SI avance  Tx SI retard       Tx SI
# 1      0.015167      0.007641    0.022808

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[0]  # Prendre le nom de la première colonne
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Nommer le DataFrame (par exemple, S1, S2, S3, etc.)
    dataframe_name = f"S{idx + 1}"
    
    # Stocker le DataFrame transformé dans le dictionnaire
    dataframes_by_interval[dataframe_name] = df_interval
    
    # Afficher le DataFrame transformé
    print(f"DataFrame {dataframe_name} transformé :")
    display(df_interval.head(2))
    print("\n")

# Accéder aux DataFrames transformés dans le dictionnaire
# Par exemple, accéder à S1
S1 = dataframes_by_interval['S1']
# Out:
# DataFrame S1 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI  Semaine 2024 35
# 0      0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1           NaN          NaN          NaN       NaN  Semaine 2024 35
# DataFrame S2 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI  Semaine 2024 36
# 0      0.920407     0.017316     0.005316  0.022632  Semaine 2024 36
# 1      0.766323     0.041237     0.013746  0.054983  Semaine 2024 36
# DataFrame S3 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI  Semaine 2024 37
# 0      0.923497     0.019879     0.002187  0.022066  Semaine 2024 37
# 1        0.7022     0.106599     0.032149  0.138748  Semaine 2024 37
# DataFrame S4 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI Tx conformite  \
# 0      0.943673     0.019833     0.000793  0.020627      0.925623
# 1      0.693182     0.022727     0.007576  0.030303      0.719428
#
# 0 Tx SI avance Tx SI retard     Tx SI  Semaine 2024 38
# 0     0.017856     0.003004   0.02086  Semaine 2024 38
# 1     0.076923     0.023669  0.100592  Semaine 2024 38

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[0]  # Prendre le nom de la première colonne
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Nommer le DataFrame (par exemple, S1, S2, S3, etc.)
    dataframe_name = f"S{idx + 1}"
    
    # Stocker le DataFrame transformé dans le dictionnaire
    dataframes_by_interval[dataframe_name] = df_interval
    
    # Afficher le DataFrame transformé
    print(f"DataFrame {dataframe_name} transformé :")
    display(df_interval.head(2))
    print("\n")

# Accéder aux DataFrames transformés dans le dictionnaire
# Par exemple, accéder à S1
S1 = dataframes_by_interval['S1']
# Out:
# DataFrame S1 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0      0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1           NaN          NaN          NaN       NaN  Semaine 2024 35
# DataFrame S2 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0      0.920407     0.017316     0.005316  0.022632  Semaine 2024 36
# 1      0.766323     0.041237     0.013746  0.054983  Semaine 2024 36
# DataFrame S3 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0      0.923497     0.019879     0.002187  0.022066  Semaine 2024 37
# 1        0.7022     0.106599     0.032149  0.138748  Semaine 2024 37
# DataFrame S4 transformé :
# 0 Tx conformite Tx SI avance Tx SI retard     Tx SI Tx conformite  \
# 0      0.943673     0.019833     0.000793  0.020627      0.925623
# 1      0.693182     0.022727     0.007576  0.030303      0.719428
#
# 0 Tx SI avance Tx SI retard     Tx SI             Date
# 0     0.017856     0.003004   0.02086  Semaine 2024 38
# 1     0.076923     0.023669  0.100592  Semaine 2024 38

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        # Trouver l'index de la colonne 'Totaux'
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            # Exclure toutes les colonnes à partir de 'Totaux' inclusivement
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[0]  # Prendre le nom de la première colonne
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Nommer le DataFrame (par exemple, S1, S2, S3, etc.)
    dataframe_name = f"S{idx + 1}"
    
    # Stocker le DataFrame transformé dans le dictionnaire
    dataframes_by_interval[dataframe_name] = df_interval
    
    # Afficher le DataFrame transformé
    print(f"DataFrame {dataframe_name} transformé :")
    display(df_interval.tail(5))
    print("\n")

# Accéder aux DataFrames transformés dans le dictionnaire
# Par exemple, accéder à S1
S1 = dataframes_by_interval['S1']
# Out:
# DataFrame S1 transformé :
# 0  Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 37           NaN          NaN          NaN       NaN  Semaine 2024 35
# 38           NaN          NaN          NaN       NaN  Semaine 2024 35
# 39      0.930016     0.032659     0.012442  0.045101  Semaine 2024 35
# 40      0.845931     0.010103     0.022451  0.032554  Semaine 2024 35
# 41      0.931777     0.013608       0.0058  0.019408  Semaine 2024 35
# DataFrame S2 transformé :
# 0  Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 37      0.940196     0.007843     0.005882  0.013725  Semaine 2024 36
# 38        0.9175         0.01         0.01      0.02  Semaine 2024 36
# 39      0.952496     0.032206            0  0.032206  Semaine 2024 36
# 40      0.855589     0.009149     0.006677  0.015826  Semaine 2024 36
# 41      0.921553     0.013807     0.008999  0.022806  Semaine 2024 36
# DataFrame S3 transformé :
# 0  Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 37         0.933        0.016        0.004      0.02  Semaine 2024 37
# 38      0.939614     0.014493            0  0.014493  Semaine 2024 37
# 39      0.953978     0.024961      0.00312  0.028081  Semaine 2024 37
# 40        0.8503     0.009998     0.005272   0.01527  Semaine 2024 37
# 41      0.920352     0.017158     0.007891  0.025049  Semaine 2024 37
# DataFrame S4 transformé :
# 0  Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 37      0.897561     0.004878     0.009756  0.014634  Semaine 2024 38
# 38         0.875     0.029412            0  0.029412  Semaine 2024 38
# 39      0.981818     0.018182            0  0.018182  Semaine 2024 38
# 40      0.884149     0.020359     0.004363  0.024721  Semaine 2024 38
# 41      0.930056     0.016524      0.00765  0.024174  Semaine 2024 38

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[0]
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Ajouter les colonnes à conserver depuis df1
    df_interval = df_interval.join(df[columns_to_keep[:-1]])
    
    # Sélectionner uniquement les colonnes à conserver
    df_filtered = df_interval[columns_to_keep]
    
    # Ajouter le DataFrame filtré à la liste
    filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 37
#      34 df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
#      36 # Ajouter les colonnes à conserver depuis df1
# ---> 37 df_interval = df_interval.join(df[columns_to_keep[:-1]])
#      39 # Sélectionner uniquement les colonnes à conserver
#      40 df_filtered = df_interval[columns_to_keep]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI'], dtype='object')] are in the [columns]"

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Vérifier si toutes les colonnes nécessaires sont dans df1
common_columns = [col for col in columns_to_keep[:-1] if col in df.columns]

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[0]
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Ajouter les colonnes communes uniquement si elles existent dans df1
    if common_columns:
        df_interval = df_interval.join(df[common_columns])

    # Sélectionner uniquement les colonnes à conserver, y compris 'Date'
    if set(columns_to_keep).issubset(df_interval.columns):
        df_filtered = df_interval[columns_to_keep]
        filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# DataFrame unique après filtrage et concaténation :
# 0   Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0        0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1             NaN          NaN          NaN       NaN  Semaine 2024 35
# 2        0.947664     0.015888            0  0.015888  Semaine 2024 35
# 3        0.980887     0.009939     0.000765  0.010703  Semaine 2024 35
# 4        0.952328     0.008869      0.00388  0.012749  Semaine 2024 35
# ..            ...          ...          ...       ...              ...
# 163      0.897561     0.004878     0.009756  0.014634  Semaine 2024 38
# 164         0.875     0.029412            0  0.029412  Semaine 2024 38
# 165      0.981818     0.018182            0  0.018182  Semaine 2024 38
# 166      0.884149     0.020359     0.004363  0.024721  Semaine 2024 38
# 167      0.930056     0.016524      0.00765  0.024174  Semaine 2024 38
#
# [168 rows x 5 columns]

# %%
final_df.head(50)
# Out:
# 0  Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0       0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1            NaN          NaN          NaN       NaN  Semaine 2024 35
# 2       0.947664     0.015888            0  0.015888  Semaine 2024 35
# 3       0.980887     0.009939     0.000765  0.010703  Semaine 2024 35
# 4       0.952328     0.008869      0.00388  0.012749  Semaine 2024 35
# 5            NaN          NaN          NaN       NaN  Semaine 2024 35
# 6       0.959989     0.008165     0.001633  0.009799  Semaine 2024 35
# 7       0.966903     0.013855     0.004002  0.017857  Semaine 2024 35
# 8       0.979186     0.008326     0.000308  0.008634  Semaine 2024 35
# 9       0.925339     0.011312     0.004309  0.015622  Semaine 2024 35
# 10      0.912613     0.009079     0.012322  0.021401  Semaine 2024 35
# 11      0.898671     0.036545     0.016196  0.052741  Semaine 2024 35
# 12        0.9416     0.007964     0.003792  0.011756  Semaine 2024 35
# 13      0.923048     0.008299     0.026405  0.034704  Semaine 2024 35
# 14      0.936541     0.026499     0.006974  0.033473  Semaine 2024 35
# 15      0.958333     0.014583     0.010417     0.025  Semaine 2024 35
# 16      0.954018     0.004537     0.001769  0.006305  Semaine 2024 35
# 17      0.965986     0.008098     0.000648  0.008746  Semaine 2024 35
# 18      0.943556     0.007526     0.002822  0.010348  Semaine 2024 35
# 19      0.977907     0.008337            0  0.008337  Semaine 2024 35
# 20      0.967647     0.017647     0.005882  0.023529  Semaine 2024 35
# 21      0.952116     0.021521     0.007174  0.028694  Semaine 2024 35
# 22      0.971079     0.014461     0.001112  0.015573  Semaine 2024 35
# 23      0.978846     0.015385     0.000962  0.016346  Semaine 2024 35
# 24      0.953435     0.022392     0.003053  0.025445  Semaine 2024 35
# 25      0.966056     0.014866     0.000496  0.015362  Semaine 2024 35
# 26      0.838578     0.031886     0.005664   0.03755  Semaine 2024 35
# 27      0.923581     0.011421     0.008062  0.019483  Semaine 2024 35
# 28           NaN          NaN          NaN       NaN  Semaine 2024 35
# 29      0.919954     0.005568     0.016241   0.02181  Semaine 2024 35
# 30      0.697183     0.274648     0.003521  0.278169  Semaine 2024 35
# 31      0.731602     0.047619     0.073593  0.121212  Semaine 2024 35
# 32           NaN          NaN          NaN       NaN  Semaine 2024 35
# 33           NaN          NaN          NaN       NaN  Semaine 2024 35
# 34           NaN          NaN          NaN       NaN  Semaine 2024 35
# 35           NaN          NaN          NaN       NaN  Semaine 2024 35
# 36           NaN          NaN          NaN       NaN  Semaine 2024 35
# 37           NaN          NaN          NaN       NaN  Semaine 2024 35
# 38           NaN          NaN          NaN       NaN  Semaine 2024 35
# 39      0.930016     0.032659     0.012442  0.045101  Semaine 2024 35
# 40      0.845931     0.010103     0.022451  0.032554  Semaine 2024 35
# 41      0.931777     0.013608       0.0058  0.019408  Semaine 2024 35
# 42      0.920407     0.017316     0.005316  0.022632  Semaine 2024 36
# 43      0.766323     0.041237     0.013746  0.054983  Semaine 2024 36
# 44      0.947853     0.011247            0  0.011247  Semaine 2024 36
# 45      0.958935     0.013538     0.002708  0.016245  Semaine 2024 36
# 46      0.966596     0.005626     0.006329  0.011955  Semaine 2024 36
# 47      0.864706     0.035294     0.011765  0.047059  Semaine 2024 36
# 48       0.92909     0.006189     0.001076  0.007266  Semaine 2024 36
# 49       0.94683     0.007402     0.002961  0.010363  Semaine 2024 36

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Vérifier si toutes les colonnes nécessaires sont dans df1
common_columns = [col for col in columns_to_keep[:-1] if col in df.columns]

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[0]
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Ajouter les colonnes communes uniquement si elles existent dans df1
    if common_columns:
        df_interval = df_interval.join(df[common_columns])
    
    # Supprimer la dernière ligne avant le filtrage
    df_interval = df_interval[:-1]
    
    # Sélectionner uniquement les colonnes à conserver, y compris 'Date'
    if set(columns_to_keep).issubset(df_interval.columns):
        df_filtered = df_interval[columns_to_keep]
        filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# DataFrame unique après filtrage et concaténation :
# 0   Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0        0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1             NaN          NaN          NaN       NaN  Semaine 2024 35
# 2        0.947664     0.015888            0  0.015888  Semaine 2024 35
# 3        0.980887     0.009939     0.000765  0.010703  Semaine 2024 35
# 4        0.952328     0.008869      0.00388  0.012749  Semaine 2024 35
# ..            ...          ...          ...       ...              ...
# 159      0.947059            0            0         0  Semaine 2024 38
# 160      0.897561     0.004878     0.009756  0.014634  Semaine 2024 38
# 161         0.875     0.029412            0  0.029412  Semaine 2024 38
# 162      0.981818     0.018182            0  0.018182  Semaine 2024 38
# 163      0.884149     0.020359     0.004363  0.024721  Semaine 2024 38
#
# [164 rows x 5 columns]

# %%
final_df.head(50)
# Out:
# 0  Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0       0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1            NaN          NaN          NaN       NaN  Semaine 2024 35
# 2       0.947664     0.015888            0  0.015888  Semaine 2024 35
# 3       0.980887     0.009939     0.000765  0.010703  Semaine 2024 35
# 4       0.952328     0.008869      0.00388  0.012749  Semaine 2024 35
# 5            NaN          NaN          NaN       NaN  Semaine 2024 35
# 6       0.959989     0.008165     0.001633  0.009799  Semaine 2024 35
# 7       0.966903     0.013855     0.004002  0.017857  Semaine 2024 35
# 8       0.979186     0.008326     0.000308  0.008634  Semaine 2024 35
# 9       0.925339     0.011312     0.004309  0.015622  Semaine 2024 35
# 10      0.912613     0.009079     0.012322  0.021401  Semaine 2024 35
# 11      0.898671     0.036545     0.016196  0.052741  Semaine 2024 35
# 12        0.9416     0.007964     0.003792  0.011756  Semaine 2024 35
# 13      0.923048     0.008299     0.026405  0.034704  Semaine 2024 35
# 14      0.936541     0.026499     0.006974  0.033473  Semaine 2024 35
# 15      0.958333     0.014583     0.010417     0.025  Semaine 2024 35
# 16      0.954018     0.004537     0.001769  0.006305  Semaine 2024 35
# 17      0.965986     0.008098     0.000648  0.008746  Semaine 2024 35
# 18      0.943556     0.007526     0.002822  0.010348  Semaine 2024 35
# 19      0.977907     0.008337            0  0.008337  Semaine 2024 35
# 20      0.967647     0.017647     0.005882  0.023529  Semaine 2024 35
# 21      0.952116     0.021521     0.007174  0.028694  Semaine 2024 35
# 22      0.971079     0.014461     0.001112  0.015573  Semaine 2024 35
# 23      0.978846     0.015385     0.000962  0.016346  Semaine 2024 35
# 24      0.953435     0.022392     0.003053  0.025445  Semaine 2024 35
# 25      0.966056     0.014866     0.000496  0.015362  Semaine 2024 35
# 26      0.838578     0.031886     0.005664   0.03755  Semaine 2024 35
# 27      0.923581     0.011421     0.008062  0.019483  Semaine 2024 35
# 28           NaN          NaN          NaN       NaN  Semaine 2024 35
# 29      0.919954     0.005568     0.016241   0.02181  Semaine 2024 35
# 30      0.697183     0.274648     0.003521  0.278169  Semaine 2024 35
# 31      0.731602     0.047619     0.073593  0.121212  Semaine 2024 35
# 32           NaN          NaN          NaN       NaN  Semaine 2024 35
# 33           NaN          NaN          NaN       NaN  Semaine 2024 35
# 34           NaN          NaN          NaN       NaN  Semaine 2024 35
# 35           NaN          NaN          NaN       NaN  Semaine 2024 35
# 36           NaN          NaN          NaN       NaN  Semaine 2024 35
# 37           NaN          NaN          NaN       NaN  Semaine 2024 35
# 38           NaN          NaN          NaN       NaN  Semaine 2024 35
# 39      0.930016     0.032659     0.012442  0.045101  Semaine 2024 35
# 40      0.845931     0.010103     0.022451  0.032554  Semaine 2024 35
# 41      0.920407     0.017316     0.005316  0.022632  Semaine 2024 36
# 42      0.766323     0.041237     0.013746  0.054983  Semaine 2024 36
# 43      0.947853     0.011247            0  0.011247  Semaine 2024 36
# 44      0.958935     0.013538     0.002708  0.016245  Semaine 2024 36
# 45      0.966596     0.005626     0.006329  0.011955  Semaine 2024 36
# 46      0.864706     0.035294     0.011765  0.047059  Semaine 2024 36
# 47       0.92909     0.006189     0.001076  0.007266  Semaine 2024 36
# 48       0.94683     0.007402     0.002961  0.010363  Semaine 2024 36
# 49      0.957199     0.006283     0.002618  0.008901  Semaine 2024 36

# %%
# Ajouter la colonne 'Ligne' à chaque intervalle dans columns_by_interval
for interval in columns_by_interval:
    columns_by_interval[interval] = ['Ligne'] + columns_by_interval[interval]

# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Ligne','Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Vérifier si toutes les colonnes nécessaires sont dans df1
common_columns = [col for col in columns_to_keep[:-1] if col in df.columns]

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Ajouter les colonnes communes uniquement si elles existent dans df1
    if common_columns:
        df_interval = df_interval.join(df[common_columns])
    
    # Supprimer la dernière ligne avant le filtrage
    df_interval = df_interval[:-1]
    
    # Sélectionner uniquement les colonnes à conserver, y compris 'Date'
    if set(columns_to_keep).issubset(df_interval.columns):
        df_filtered = df_interval[columns_to_keep]
        filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 26
#      23         columns = columns[:total_index]
#      25 # Créer un DataFrame pour chaque intervalle
# ---> 26 df_interval = df[columns].copy()
#      28 # Récupérer le nom de la colonne de date
#      29 date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Ligne'] not in index"

# %%
filename = 'C:/Users/albert-marc.talla/Desktop/test/Taux de régularité DSP - 18092024131617.xlsx'

df = pd.read_excel(filename, header=11)

# %%
print(df.head(2))
# Out:
#      Transporteur Semaine 2024 35    Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0           Ligne   Tx conformite  Tx SI avance  Tx SI retard      Tx SI
# 1  DSP19 - SENART        0.931777      0.013608        0.0058   0.019408
#
#   Semaine 2024 36    Unnamed: 6    Unnamed: 7 Unnamed: 8 Semaine 2024 37  ...  \
# 0   Tx conformite  Tx SI avance  Tx SI retard      Tx SI   Tx conformite  ...
# 1        0.921553      0.013807      0.008999   0.022806        0.920352  ...
#
#     Unnamed: 11 Unnamed: 12 Semaine 2024 38   Unnamed: 14   Unnamed: 15  \
# 0  Tx SI retard       Tx SI   Tx conformite  Tx SI avance  Tx SI retard
# 1      0.007891    0.025049        0.930056      0.016524       0.00765
#
#   Unnamed: 16         Totaux   Unnamed: 18   Unnamed: 19 Unnamed: 20
# 0       Tx SI  Tx conformite  Tx SI avance  Tx SI retard       Tx SI
# 1    0.024174       0.924892      0.015167      0.007641    0.022808
#
# [2 rows x 21 columns]

# %%
# Fonction pour récupérer les paires start_week et end_week, incluant la dernière semaine si non suivie
def get_week_intervals(df):
    week_columns = [col for col in df.columns if 'Semaine' in col]
    intervals = []
    for i in range(len(week_columns) - 1):
        start_week = week_columns[i]
        end_week = week_columns[i + 1]
        intervals.append((start_week, end_week))
    # Ajouter la dernière semaine seule si elle n'a pas d'intervalle suivant
    if len(week_columns) > 0:
        intervals.append((week_columns[-1], None))
    return intervals

# Fonction pour récupérer les colonnes entre deux semaines, incluant le cas où end_week est None
def get_columns_between_weeks_exclusive(df, start_week, end_week):
    selected_columns = []
    include = False
    for col in df.columns:
        if start_week in col:
            include = True
        if include:
            # Si end_week est None, inclure toutes les colonnes restantes
            if end_week is None:
                selected_columns.append(col)
            # Sinon, arrêter l'inclusion avant d'atteindre end_week
            elif end_week in col:
                break
            else:
                selected_columns.append(col)
    return selected_columns

# Récupérer les paires de semaines
week_intervals = get_week_intervals(df)

# Initialiser un dictionnaire pour stocker les colonnes par intervalle
columns_by_interval = {}

# Boucle sur chaque intervalle (start_week, end_week) pour récupérer les colonnes
for start_week, end_week in week_intervals:
    # Récupérer les colonnes pour cet intervalle spécifique
    interval_columns = get_columns_between_weeks_exclusive(df, start_week, end_week)
    # Stocker le résultat dans le dictionnaire avec l'intervalle comme clé
    columns_by_interval[(start_week, end_week)] = interval_columns

# Afficher les colonnes pour chaque intervalle
for interval, columns in columns_by_interval.items():
    print(f"Intervalle {interval}: {columns}")
# Out:
# Intervalle ('Semaine 2024 35', 'Semaine 2024 36'): ['Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']
# Intervalle ('Semaine 2024 36', 'Semaine 2024 37'): ['Semaine 2024 36', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']
# Intervalle ('Semaine 2024 37', 'Semaine 2024 38'): ['Semaine 2024 37', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12']
# Intervalle ('Semaine 2024 38', None): ['Semaine 2024 38', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Totaux', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']

# %%
 df['Ligne']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ligne'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df['Ligne']
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Ligne'

# %%
# Vérifiez si 'Ligne' est dans les colonnes, sinon ajoutez-la
if 'Ligne' not in df.columns:
    df['Ligne'] = range(1, len(df) + 1)  # Ajoute une colonne 'Ligne' avec des valeurs numériques
    

# Ajouter la colonne 'Ligne' à chaque intervalle dans columns_by_interval
for interval in columns_by_interval:
    columns_by_interval[interval] = ['Ligne'] + columns_by_interval[interval]

# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Ligne', 'Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Vérifier si toutes les colonnes nécessaires sont dans df
common_columns = [col for col in columns_to_keep[:-1] if col in df.columns]

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Ajouter les colonnes communes uniquement si elles existent dans df
    if common_columns:
        df_interval = df_interval.join(df[common_columns])
    
    # Supprimer la dernière ligne avant le filtrage
    df_interval = df_interval[:-1]
    
    # Sélectionner uniquement les colonnes à conserver, y compris 'Date'
    if set(columns_to_keep).issubset(df_interval.columns):
        df_filtered = df_interval[columns_to_keep]
        filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# DataFrame unique après filtrage et concaténation :
#      Ligne Tx conformite Tx SI avance Tx SI retard     Tx SI             Date
# 0        1      0.926288     0.015576     0.002528  0.018104  Semaine 2024 35
# 1        2           NaN          NaN          NaN       NaN  Semaine 2024 35
# 2        3      0.947664     0.015888            0  0.015888  Semaine 2024 35
# 3        4      0.980887     0.009939     0.000765  0.010703  Semaine 2024 35
# 4        5      0.952328     0.008869      0.00388  0.012749  Semaine 2024 35
# ..     ...           ...          ...          ...       ...              ...
# 159     37      0.947059            0            0         0  Semaine 2024 38
# 160     38      0.897561     0.004878     0.009756  0.014634  Semaine 2024 38
# 161     39         0.875     0.029412            0  0.029412  Semaine 2024 38
# 162     40      0.981818     0.018182            0  0.018182  Semaine 2024 38
# 163     41      0.884149     0.020359     0.004363  0.024721  Semaine 2024 38
#
# [164 rows x 6 columns]

# %%
# Ajouter la colonne 'Ligne' à chaque intervalle dans columns_by_interval
for interval in columns_by_interval:
    columns_by_interval[interval] = ['Ligne'] + columns_by_interval[interval]

# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Ligne', 'Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Vérifier si toutes les colonnes nécessaires sont dans df
common_columns = [col for col in columns_to_keep[:-1] if col in df.columns]

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Ajouter les colonnes communes uniquement si elles existent dans df
    if common_columns:
        df_interval = df_interval.join(df[common_columns])
    
    # Supprimer la dernière ligne avant le filtrage
    df_interval = df_interval[:-1]
    
    # Sélectionner uniquement les colonnes à conserver, y compris 'Date'
    if set(columns_to_keep).issubset(df_interval.columns):
        df_filtered = df_interval[columns_to_keep]
        filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 26
#      23         columns = columns[:total_index]
#      25 # Créer un DataFrame pour chaque intervalle
# ---> 26 df_interval = df[columns].copy()
#      28 # Récupérer le nom de la colonne de date
#      29 date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Ligne'] not in index"

# %%
# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Ligne', 'Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Vérifier si toutes les colonnes nécessaires sont dans df
common_columns = [col for col in columns_to_keep[:-1] if col in df.columns]

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
    
    # Utiliser la première ligne comme en-tête des colonnes
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Ajouter la colonne 'Date' au DataFrame avec la valeur de la date récupérée
    df_interval['Date'] = date_S1
    
    # Ajouter les colonnes communes uniquement si elles existent dans df
    if common_columns:
        df_interval = df_interval.join(df[common_columns])
    
    # Supprimer la dernière ligne avant le filtrage
    df_interval = df_interval[:-1]
    
    # Sélectionner uniquement les colonnes à conserver, y compris 'Date'
    if set(columns_to_keep).issubset(df_interval.columns):
        df_filtered = df_interval[columns_to_keep]
        filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 22
#      19         columns = columns[:total_index]
#      21 # Créer un DataFrame pour chaque intervalle
# ---> 22 df_interval = df[columns].copy()
#      24 # Récupérer le nom de la colonne de date
#      25 date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Ligne'] not in index"

# %%
# Supposons que columns_by_interval ait été créé comme dans l'exemple précédent
columns_by_interval = {
    ('Semaine 2024 35', 'Semaine 2024 36'): ['Ligne', 'Semaine 2024 35', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],
    ('Semaine 2024 36', 'Semaine 2024 37'): ['Ligne', 'Semaine 2024 36', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
    ('Semaine 2024 37', 'Semaine 2024 38'): ['Ligne', 'Semaine 2024 37', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
    ('Semaine 2024 38', None): ['Ligne', 'Semaine 2024 38', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Totaux', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']
}

# Dictionnaire pour stocker les DataFrames par intervalle
dataframes_by_interval = {}

# Liste des colonnes à conserver
columns_to_keep = ['Ligne', 'Tx conformite', 'Tx SI avance', 'Tx SI retard', 'Tx SI', 'Date']

# Vérifier si toutes les colonnes nécessaires sont dans df
common_columns = [col for col in columns_to_keep[:-1] if col in df.columns]

# Liste pour stocker les DataFrames filtrés
filtered_dfs = []

# Boucle sur chaque intervalle dans columns_by_interval
for idx, (interval, columns) in enumerate(columns_by_interval.items()):
    # Si c'est le dernier intervalle, exclure les colonnes à partir de 'Totaux'
    if idx == len(columns_by_interval) - 1:
        if 'Totaux' in columns:
            total_index = columns.index('Totaux')
            columns = columns[:total_index]
    
    # Créer un DataFrame pour chaque intervalle
    df_interval = df[columns].copy()
    
    # Récupérer le nom de la colonne de date
    date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
    
    # Ajouter la colonne 'Date' au DataFrame
    df_interval['Date'] = date_S1
    
    # Renommer les colonnes avec la première ligne
    df_interval.columns = df_interval.iloc[0]
    
    # Supprimer les deux premières lignes et réinitialiser l'index
    df_interval = df_interval[2:].reset_index(drop=True)
    
    # Renommer la colonne 'Semaine XXXX XX' en 'Date'
    df_interval.rename(columns={date_S1: 'Date'}, inplace=True)
    
    # Sélectionner uniquement les colonnes à conserver, y compris 'Date'
    if set(columns_to_keep).issubset(df_interval.columns):
        df_filtered = df_interval[columns_to_keep]
        filtered_dfs.append(df_filtered)

# Concaténer tous les DataFrames filtrés en un seul DataFrame
final_df = pd.concat(filtered_dfs, ignore_index=True)

# Afficher le DataFrame final
print("DataFrame unique après filtrage et concaténation :")
display(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 30
#      27         columns = columns[:total_index]
#      29 # Créer un DataFrame pour chaque intervalle
# ---> 30 df_interval = df[columns].copy()
#      32 # Récupérer le nom de la colonne de date
#      33 date_S1 = df_interval.columns.to_list()[1]  # Prendre le nom de la deuxième colonne (car la première est 'Ligne')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Ligne'] not in index"
